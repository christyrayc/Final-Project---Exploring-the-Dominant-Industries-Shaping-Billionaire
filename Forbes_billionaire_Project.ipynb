# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('./data/forbes billionaire list cleaned .csv')

# %%
df
# Out:
#       rank                      name  net_worth (in billion $)   age  \
# 0        1  Bernard Arnault & family                     211.0  74.0
# 1        2                 Elon Musk                     180.0  51.0
# 2        3                Jeff Bezos                     114.0  59.0
# 3        4             Larry Ellison                     107.0  78.0
# 4        5            Warren Buffett                     106.0  92.0
# ...    ...                       ...                       ...   ...
# 2650  2540          Danilo Iervolino                       1.0  45.0
# 2651  2540               Michael Kum                       1.0  78.0
# 2652  2540               Scott Smith                       1.0  73.0
# 2653  2540    Wen Pengcheng & family                       1.0  60.0
# 2654  2540              Neerja Sethi                       1.0  68.0
#
#      country / territory                      source               industry  \
# ...

# %%
# Check for NaN values 
nan_values = df.isna().value_counts()
nan_values
# Out:
# rank   name   net_worth (in billion $)  age    country / territory  source  industry  GDP(in million)
# False  False  False                     False  False                False   False     False              2588
#                                         True   False                False   False     False                67
# dtype: int64

# %%
df.dropna(axis = 0 ,inplace = True)

# %%
df.tail()
# Out:
#       rank                    name  net_worth (in billion $)   age  \
# 2650  2540        Danilo Iervolino                       1.0  45.0
# 2651  2540             Michael Kum                       1.0  78.0
# 2652  2540             Scott Smith                       1.0  73.0
# 2653  2540  Wen Pengcheng & family                       1.0  60.0
# 2654  2540            Neerja Sethi                       1.0  68.0
#
#      country / territory                      source         industry  \
# 2650               Italy         Online universities       Technology
# 2651           Singapore                      Hotels      Real Estate
# 2652       United States             Cloud computing       Technology
# 2653               China                Agribusiness  Food & Beverage
# 2654       United States  IT consulting, outsourcing       Technology
#
#      GDP(in million)
# 2650             2.1
# 2651            515k
# 2652           26.85
# 2653            19.3
# 2654           26.85

# %%
df.duplicated().value_counts()
# Out:
# False    2575
# True       13
# dtype: int64

# %%
# Check for duplicated rows
duplicated_rows = df.duplicated()
duplicated_df = df[duplicated_rows]
duplicated_df 
#since the ranks are wahat makes this rows duplicates we will leave them rather than dropping the, because it well our analysis later on
# Out:
#       rank                          name  net_worth (in billion $)   age  \
# 2553  2540           Lu Yonghua & family                       1.0  59.0
# 2561  2540                     Ma Xiuhui                       1.0  52.0
# 2573  2540  Vera Rechulski Santo Domingo                       1.0  74.0
# 2589  2540                   Tyler Perry                       1.0  53.0
# 2597  2540                 Stanley Motta                       1.0  77.0
# 2605  2540       Fulvio Montipò & family                       1.0  78.0
# 2614  2540              Andrei Molchanov                       1.0  51.0
# 2622  2540                Ulrike Meister                       1.0  56.0
# 2633  2540                 Apoorva Mehta                       1.0  36.0
# 2645  2540     Eddy Kusnadi Sariaatmadja                       1.0  69.0
# 2647  2540             George Sakellaris                       1.0  76.0
# 2652  2540                   Scott Smith                       1.0  73.0
# ...

# %%
df
# Out:
#       rank                      name  net_worth (in billion $)   age  \
# 0        1  Bernard Arnault & family                     211.0  74.0
# 1        2                 Elon Musk                     180.0  51.0
# 2        3                Jeff Bezos                     114.0  59.0
# 3        4             Larry Ellison                     107.0  78.0
# 4        5            Warren Buffett                     106.0  92.0
# ...    ...                       ...                       ...   ...
# 2650  2540          Danilo Iervolino                       1.0  45.0
# 2651  2540               Michael Kum                       1.0  78.0
# 2652  2540               Scott Smith                       1.0  73.0
# 2653  2540    Wen Pengcheng & family                       1.0  60.0
# 2654  2540              Neerja Sethi                       1.0  68.0
#
#      country / territory                      source               industry  \
# ...

# %%
#distrubution of family wealth in the forbes list 2023
filtered_df = df[df['name'].str.contains('family', case=False)]
filtered_df
# Out:
#       rank                                   name  net_worth (in billion $)  \
# 0        1               Bernard Arnault & family                     211.0
# 7        8              Carlos Slim Helu & family                      93.0
# 10      11  Francoise Bettencourt Meyers & family                      80.5
# 17      17                    Julia Koch & family                      59.0
# 21      22                 David Thomson & family                      54.4
# ...    ...                                    ...                       ...
# 2606  2540                    David Tran & family                       1.0
# 2616  2540                  Yi Xianzhong & family                       1.0
# 2636  2540                     Hu Gengxi & family                       1.0
# 2649  2540                      Du Yulin & family                       1.0
# 2653  2540                 Wen Pengcheng & family                       1.0
#
# ...

# %%
#Top 50 richest families on the list 

top_300_richest_families = filtered_df.nlargest(300, 'net_worth (in billion $)')

# %%
# Display the result
print(top_300_richest_families[['name', 'net_worth (in billion $)', 'country / territory', 'industry']])
# Out:
#                                        name  net_worth (in billion $)  \
# 0                  Bernard Arnault & family                     211.0
# 7                 Carlos Slim Helu & family                      93.0
# 10    Francoise Bettencourt Meyers & family                      80.5
# 17                      Julia Koch & family                      59.0
# 21                   David Thomson & family                      54.4
# ...                                     ...                       ...
# 2370              Axel Oberwelland & family                       1.2
# 2380                   Alan Miller & family                       1.2
# 2384                     Xu Shijun & family                       1.2
# 2389               Jeffrey Michael & family                       1.2
# 2392               Sandro Veronesi & family                       1.2
#
#      country / territory               industry
# 0                 France       Fashion & Retail
# ...

# %%
top_300_richest_families = filtered_df.nlargest(300, 'net_worth (in billion $)')

# Create a bar chart to visualize net worth based on industry
plt.figure(figsize=(12, 6))
plt.bar(filtered_df['industry'], filtered_df['net_worth (in billion $)'])
plt.xlabel('Industry')
plt.ylabel('Net Worth (in billion $)')
plt.title(' Richest Families by Industry')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Group the data by 'country / territory' and calculate the total net worth for each country
country_wealth = df.groupby('country / territory')['net_worth (in billion $)'].sum()

# Group the data by 'industry' and calculate the total net worth for each industry
industry_wealth = df.groupby('industry')['net_worth (in billion $)'].sum()

# Print the results
print("Wealth Distribution Across Countries:")
print(country_wealth)

print("\nWealth Distribution Across Industries:")
print(industry_wealth)
# Out:
# Wealth Distribution Across Countries:
# country / territory
# Algeria              4.6
# Argentina            7.9
# Armenia              1.2
# Australia          183.5
# Austria             70.7
#                    ...
# United Kingdom     199.8
# United States     4494.8
# Venezuela            4.3
# Vietnam             12.6
# Zimbabwe             1.9
# Name: net_worth (in billion $), Length: 77, dtype: float64
#
# Wealth Distribution Across Industries:
# industry
# Automotive                     523.4
# Construction & Engineering     117.4
# Diversified                    891.7
# Energy                         449.2
# Fashion & Retail              1659.9
# Finance & Investments         1587.4
# Food & Beverage                937.1
# Gambling & Casinos             120.5
# Healthcare                     633.3
# Logistics                      238.5
# Manufacturing                 1009.3
# Media & Entertainment          422.2
# Metals & Mining                445.4
# ...

# %%
# # Analyzing wealth distribution across countries and industries

# Plot the wealth distribution across countries
plt.figure(figsize=(10, 6))
country_wealth.plot(kind='bar')
plt.title('Wealth Distribution Across Countries')
plt.xlabel('Country / Territory')
plt.ylabel('Total Net Worth (in billion $)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Plot the wealth distribution across industries
plt.figure(figsize=(10, 6))
industry_wealth.plot(kind='bar')
plt.title('Wealth Distribution Across Industries')
plt.xlabel('Industry')
plt.ylabel('Total Net Worth (in billion $)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# # Identifying the top sources of wealth and the most successful industries

# In[33]:


# Group the data by 'source' and calculate the total net worth for each source
source_wealth = df.groupby('source')['net_worth (in billion $)'].sum()

# Group the data by 'industry' and calculate the total net worth for each industry
industry_wealth = df.groupby('industry')['net_worth (in billion $)'].sum()

# Find the top sources of wealth
top_sources = source_wealth.nlargest(30)


# Find the most successful industries
most_successful_industries = industry_wealth.nlargest(18)

print("Top Sources of Wealth:")
print(top_sources)

print("\nMost Successful Industries:")
print(most_successful_industries)
# Out:
# Top Sources of Wealth:
# source
# Real estate           533.3
# Diversified           384.4
# Investments           336.7
# Hedge funds           271.3
# Pharmaceuticals       252.0
# Walmart               220.9
# LVMH                  211.0
# Microsoft             196.4
# Google                189.0
# Tesla, SpaceX         180.0
# Shipping              179.8
# Private equity        164.6
# Software              164.6
# Telecom               155.1
# Retail                145.2
# Mining                138.9
# Amazon                138.4
# Chemicals             137.2
# Koch Industries       118.0
# Candy, pet food       115.0
# Berkshire Hathaway    110.8
# E-commerce            108.4
# Oracle                107.0
# Bloomberg LP          104.3
# Facebook               90.4
# Banking                87.3
# Medical devices        85.8
# Luxury goods           85.3
# Zara                   84.2
# Media                  84.0
# Name: net_worth (in billion $), dtype: float64
#
# ...

# %%
# Visualize the top sources of wealth
plt.figure(figsize=(10, 6))
top_sources.plot(kind='bar', color='skyblue')
plt.title('Top Sources of Wealth')
plt.xlabel('Source')
plt.ylabel('Total Net Worth (in billion $)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Visualize the most successful industries
plt.figure(figsize=(10, 6))
most_successful_industries.plot(kind='bar', color='lightgreen')
plt.title('Most Successful Industries')
plt.xlabel('Industry')
plt.ylabel('Total Net Worth (in billion $)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
unique_industries_count = df['source'].nunique()
unique_industries_count
# Out:
# 893

# %%
df.columns
# Out:
# Index(['rank', 'name', 'net_worth (in billion $)', 'age',
#        'country / territory', 'source', 'industry', 'GDP(in million)'],
#       dtype='object')

# %%
# # Exploring the demographic characteristics of billionaires

# In[38]:


# Create a histogram for the age distribution
plt.hist(df['age'], bins=20, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Number of Billionaires')
plt.title('Age Distribution of Billionaires')
plt.show()

# %%
# Create a histogram for the net worth distribution
plt.hist(df['net_worth (in billion $)'], bins=20, edgecolor='black')
plt.xlabel('Net Worth (in billion $)')
plt.ylabel('Number of Billionaires')
plt.title('Net Worth Distribution of Billionaires')
plt.show()

# %%
# Group the data by country and count the number of billionaires in each country
country_counts = df['country / territory'].value_counts()

# Create a bar chart for the distribution of billionaires across countries
plt.bar(country_counts.index, country_counts.values)
plt.xlabel('Country / Territory')
plt.ylabel('Number of Billionaires')
plt.title('Distribution of Billionaires Across Countries')
plt.xticks(rotation=90)
plt.show()

# %%
plt.barh(country_counts.index, country_counts.values)
plt.xlabel('Number of Billionaires')
plt.ylabel('Country / Territory')
plt.title('Distribution of Billionaires Across Countries')
plt.show()

# %%
industry_counts = df['industry'].value_counts()

plt.figure(figsize=(12, 6))
plt.bar(country_counts.index, country_counts.values, label='By Country', alpha=0.7)
plt.bar(industry_counts.index, industry_counts.values, label='By Industry', alpha=0.7)
plt.xlabel('Country / Territory and Industry')
plt.ylabel('Number of Billionaires')
plt.title('Distribution of Billionaires Across Countries and Industries')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
df
# Out:
#       rank                      name  net_worth (in billion $)   age  \
# 0        1  Bernard Arnault & family                     211.0  74.0
# 1        2                 Elon Musk                     180.0  51.0
# 2        3                Jeff Bezos                     114.0  59.0
# 3        4             Larry Ellison                     107.0  78.0
# 4        5            Warren Buffett                     106.0  92.0
# ...    ...                       ...                       ...   ...
# 2650  2540          Danilo Iervolino                       1.0  45.0
# 2651  2540               Michael Kum                       1.0  78.0
# 2652  2540               Scott Smith                       1.0  73.0
# 2653  2540    Wen Pengcheng & family                       1.0  60.0
# 2654  2540              Neerja Sethi                       1.0  68.0
#
#      country / territory                      source               industry  \
# ...

# %%
df.rename(columns={'GDP(in million)': 'GDP'}, inplace=True)

# %%
# Apply classification using loc function
df.loc[df['GDP'].str.endswith('k'), 'GDP_Classification'] = 'Less than 1M'
df.loc[~df['GDP'].str.endswith('k'), 'GDP_Classification'] = '1M or more'

# %%
# Display the updated DataFrame
print(df)
# Out:
#       rank                      name  net_worth (in billion $)   age  \
# 0        1  Bernard Arnault & family                     211.0  74.0
# 1        2                 Elon Musk                     180.0  51.0
# 2        3                Jeff Bezos                     114.0  59.0
# 3        4             Larry Ellison                     107.0  78.0
# 4        5            Warren Buffett                     106.0  92.0
# ...    ...                       ...                       ...   ...
# 2650  2540          Danilo Iervolino                       1.0  45.0
# 2651  2540               Michael Kum                       1.0  78.0
# 2652  2540               Scott Smith                       1.0  73.0
# 2653  2540    Wen Pengcheng & family                       1.0  60.0
# 2654  2540              Neerja Sethi                       1.0  68.0
#
#      country / territory                      source               industry  \
# ...

# %%
df
# Out:
#       rank                      name  net_worth (in billion $)   age  \
# 0        1  Bernard Arnault & family                     211.0  74.0
# 1        2                 Elon Musk                     180.0  51.0
# 2        3                Jeff Bezos                     114.0  59.0
# 3        4             Larry Ellison                     107.0  78.0
# 4        5            Warren Buffett                     106.0  92.0
# ...    ...                       ...                       ...   ...
# 2650  2540          Danilo Iervolino                       1.0  45.0
# 2651  2540               Michael Kum                       1.0  78.0
# 2652  2540               Scott Smith                       1.0  73.0
# 2653  2540    Wen Pengcheng & family                       1.0  60.0
# 2654  2540              Neerja Sethi                       1.0  68.0
#
#      country / territory                      source               industry  \
# ...

# %%
df["country / territory"].unique()
# Out:
# array(['France', 'United States', 'Mexico', 'India', 'Spain', 'China',
#        'Canada', 'Germany', 'Italy', 'Hong Kong', 'Austria', 'Japan',
#        'Switzerland', 'Australia', 'Indonesia', 'Russia', 'Chile',
#        'United Kingdom', 'Israel', 'Brazil', 'Czech Republic',
#        'Singapore', 'Sweden', 'Thailand', 'Netherlands', 'Nigeria',
#        'Cyprus', 'Malaysia', 'United Arab Emirates', 'South Africa',
#        'Philippines', 'New Zealand', 'Monaco', 'Belgium', 'South Korea',
#        'Taiwan', 'Norway', 'Egypt', 'Denmark', 'Ireland',
#        'Eswatini (Swaziland)', 'Colombia', 'Poland', 'Ukraine', 'Greece',
#        'Turkey', 'Georgia', 'Portugal', 'Kazakhstan', 'Algeria',
#        'Venezuela', 'Vietnam', 'Finland', 'Belize', 'Argentina',
#        'Lebanon', 'Oman', 'Iceland', 'Liechtenstein', 'Guernsey',
#        'Bulgaria', 'Romania', 'Zimbabwe', 'Qatar', 'Nepal', 'Slovakia',
#        'Peru', 'Morocco', 'Hungary', 'Tanzania', 'Barbados', 'Estonia',
# ...

# %%
df.to_csv(r"C:\Users\HP 8TH GEN I5\Downloads\forbes billionaire list cleanedx.csv")

# %%
df
# Out:
#       rank                      name  net_worth (in billion $)   age  \
# 0        1  Bernard Arnault & family                     211.0  74.0
# 1        2                 Elon Musk                     180.0  51.0
# 2        3                Jeff Bezos                     114.0  59.0
# 3        4             Larry Ellison                     107.0  78.0
# 4        5            Warren Buffett                     106.0  92.0
# ...    ...                       ...                       ...   ...
# 2650  2540          Danilo Iervolino                       1.0  45.0
# 2651  2540               Michael Kum                       1.0  78.0
# 2652  2540               Scott Smith                       1.0  73.0
# 2653  2540    Wen Pengcheng & family                       1.0  60.0
# 2654  2540              Neerja Sethi                       1.0  68.0
#
#      country / territory                      source               industry  \
# ...

# %%
continent = {'Canada': 'North America',
'Germany': 'Europe',
'Italy': 'Europe',
'Hong Kong': 'Asia',
'Austria': 'Europe',
'Japan': 'Asia',
'Switzerland': 'Europe',
'Australia': 'Australia',
'Indonesia': 'Asia',
'Russia': 'Europe',
'Chile': 'South America',
'United Kingdom': 'Europe',
'Israel': 'Asia',
'Brazil': 'South America',
'Czech Republic': 'Europe',
'Singapore': 'Asia',
'Sweden': 'Europe',
'Thailand': 'Asia',
'Netherlands': 'Europe',
'Nigeria': 'Africa',
'Cyprus': 'Europe',
'Malaysia': 'Asia',
'United Arab Emirates': 'Asia',
'South Africa': 'Africa',
'Philippines': 'Asia',
'New Zealand': 'Oceania',
'Monaco': 'Europe',
'Belgium': 'Europe',
'South Korea': 'Asia',
'Taiwan': 'Asia',
'Norway': 'Europe',
'Egypt': 'Africa',
'Denmark': 'Europe',
'Ireland': 'Europe',
'Eswatini' : 'Africa',
'Colombia': 'South America',
'Poland': 'Europe',
'Ukraine': 'Europe',
'Greece': 'Europe',
'Turkey': 'Asia' ,
'Georgia': 'Europe',
'Portugal': 'Europe',
'Kazakhstan': 'Asia',
'Algeria': 'Africa',
'Venezuela': 'South America',
'Vietnam': 'Asia',
'Finland': 'Europe',
'Belize': 'North America',
'Argentina': 'South America',
'Lebanon': 'Asia',
'Oman': 'Asia',
'Iceland': 'Europe',
'Liechtenstein': 'Europe',
'Guernsey': 'Europe',
'Bulgaria': 'Europe',
'Romania': 'Europe',
'Zimbabwe': 'Africa',
'Qatar': 'Asia' ,
'Nepal': 'Asia',
'Slovakia': 'Europe',
'Peru': 'South America',
'Morocco': 'Africa',
'Hungary': 'Europe',
'Tanzania': 'Africa',
'Barbados': 'North America',
'Estonia': 'Europe',
'Macau': 'Asia',
'St. Kitts and Nevis': 'North America',
'Armenia': 'Europe',
"Bangladesh": 'Asia',
"Panama": 'North America',
'United States': 'North America',
'France': 'Europe',
'Mexico': 'North America',
'India': 'Asia',
'Spain': 'Europe',
'China': 'Asia',
'United Kingdom': 'Europe',
'Eswatini (Swaziland)': "Africa"}

# %%
# Create a new column 'Continent' using the mapping
df['Continent'] = df['country / territory'].map(continent)

# %%
# Display the updated DataFrame
print(df)
# Out:
#       rank                      name  net_worth (in billion $)   age  \
# 0        1  Bernard Arnault & family                     211.0  74.0
# 1        2                 Elon Musk                     180.0  51.0
# 2        3                Jeff Bezos                     114.0  59.0
# 3        4             Larry Ellison                     107.0  78.0
# 4        5            Warren Buffett                     106.0  92.0
# ...    ...                       ...                       ...   ...
# 2650  2540          Danilo Iervolino                       1.0  45.0
# 2651  2540               Michael Kum                       1.0  78.0
# 2652  2540               Scott Smith                       1.0  73.0
# 2653  2540    Wen Pengcheng & family                       1.0  60.0
# 2654  2540              Neerja Sethi                       1.0  68.0
#
#      country / territory                      source               industry  \
# ...

# %%
df
# Out:
#       rank                      name  net_worth (in billion $)   age  \
# 0        1  Bernard Arnault & family                     211.0  74.0
# 1        2                 Elon Musk                     180.0  51.0
# 2        3                Jeff Bezos                     114.0  59.0
# 3        4             Larry Ellison                     107.0  78.0
# 4        5            Warren Buffett                     106.0  92.0
# ...    ...                       ...                       ...   ...
# 2650  2540          Danilo Iervolino                       1.0  45.0
# 2651  2540               Michael Kum                       1.0  78.0
# 2652  2540               Scott Smith                       1.0  73.0
# 2653  2540    Wen Pengcheng & family                       1.0  60.0
# 2654  2540              Neerja Sethi                       1.0  68.0
#
#      country / territory                      source               industry  \
# ...

# %%
# Find the top 10 richest people by continent
top_richest_by_continent = df.groupby('Continent').apply(lambda x: x.nlargest(10, 'net_worth (in billion $)')).reset_index(drop=True)

# Find the richest continent by sum of billionaires
richest_continent = df.groupby('Continent')['net_worth (in billion $)'].sum().idxmax()

print("Top 10 Richest People by Continent:")
print(top_richest_by_continent)

print("\nRichest Continent by Sum of Billionaires:")
print(richest_continent)
# Out:
# Top 10 Richest People by Continent:
#     rank                              name  net_worth (in billion $)   age  \
# 0    124                     Aliko Dangote                      14.2  65.0
# 1    157            Johann Rupert & family                      11.1  72.0
# 2    242        Nicky Oppenheimer & family                       8.4  77.0
# 3    249                  Abdulsamad Rabiu                       8.2  62.0
# 4    305                    Nassef Sawiris                       7.4  62.0
# ..   ...                               ...                       ...   ...
# 58   232  Carlos Alberto Sicupira & family                       8.6  75.0
# 59   397             Luis Carlos Sarmiento                       6.4  90.0
# 60   466                       Jean Salata                       5.5  57.0
# 61   511                 Alexandre Behring                       5.2  56.0
# 62   580                     Andre Esteves                       4.7  54.0
#
# ...

# %%
# Sum wealth by continent
wealth_by_continent = df.groupby('Continent')['net_worth (in billion $)'].sum()

# Rank continents by wealth
ranked_continents = wealth_by_continent.sort_values(ascending=False)

print("Wealth by Continent:")
print(ranked_continents)
# Out:
# Wealth by Continent:
# Continent
# North America    4916.2
# Asia             3699.6
# Europe           2924.7
# South America     234.9
# Australia         183.5
# Africa             90.5
# Oceania            12.7
# Name: net_worth (in billion $), dtype: float64

# %%
# Group the data by Continent and Country, then sum the wealth
wealth_by_country = df.groupby(['Continent', 'country / territory'])['net_worth (in billion $)'].sum()

# Sort the wealth by continent and country
sorted_wealth_by_country = wealth_by_country.groupby('Continent', group_keys=False).apply(lambda x: x.sort_values(ascending=False))

# Get the top 5 countries in each continent
top_countries_by_continent = sorted_wealth_by_country.groupby('Continent').head(5)

print("Top 5 Countries by Continent:")
print(top_countries_by_continent)
# Out:
# Top 5 Countries by Continent:
# Continent      country / territory
# Africa         Nigeria                   28.5
#                South Africa              25.6
#                Egypt                     19.1
#                Eswatini (Swaziland)       6.5
#                Algeria                    4.6
# Asia           China                   1635.2
#                India                    674.8
#                Hong Kong                344.5
#                Japan                    149.7
#                Indonesia                139.4
# Australia      Australia                183.5
# Europe         France                   587.9
#                Germany                  512.8
#                Russia                   474.5
#                Italy                    212.0
#                Switzerland              206.3
# North America  United States           4494.8
#                Canada                   243.9
#                Mexico                   168.9
# ...

# %%
# Group the data by Country and sum the wealth
wealth_by_country = df.groupby('country / territory')['net_worth (in billion $)'].sum()

# Sort the wealth by country
sorted_wealth_by_country = wealth_by_country.sort_values(ascending=False)

# Get the top 20 countries by wealth
top_countries_by_wealth = sorted_wealth_by_country.head(20)

print("Top 20 Countries by Wealth:")
print(top_countries_by_wealth)
# Out:
# Top 20 Countries by Wealth:
# country / territory
# United States     4494.8
# China             1635.2
# India              674.8
# France             587.9
# Germany            512.8
# Russia             474.5
# Hong Kong          344.5
# Canada             243.9
# Italy              212.0
# Switzerland        206.3
# United Kingdom     199.8
# Australia          183.5
# Mexico             168.9
# Brazil             160.2
# Japan              149.7
# Sweden             140.4
# Indonesia          139.4
# Spain              134.1
# Taiwan             132.4
# Singapore          118.9
# Name: net_worth (in billion $), dtype: float64

# %%
# Group the data by Country and sum the wealth
wealth_by_country = df.groupby('country / territory')['net_worth (in billion $)'].sum()

# Sort the wealth by country
sorted_wealth_by_country = wealth_by_country.sort_values(ascending=False)

# Get the top 20 countries by wealth
top_countries_by_wealth = sorted_wealth_by_country.head(20)

print("Top 20 Countries by Wealth:")
print(top_countries_by_wealth)
# Out:
# Top 20 Countries by Wealth:
# country / territory
# United States     4494.8
# China             1635.2
# India              674.8
# France             587.9
# Germany            512.8
# Russia             474.5
# Hong Kong          344.5
# Canada             243.9
# Italy              212.0
# Switzerland        206.3
# United Kingdom     199.8
# Australia          183.5
# Mexico             168.9
# Brazil             160.2
# Japan              149.7
# Sweden             140.4
# Indonesia          139.4
# Spain              134.1
# Taiwan             132.4
# Singapore          118.9
# Name: net_worth (in billion $), dtype: float64

# %%
# Group the data by Continent and sum the wealth
wealth_by_continent = df.groupby('Continent')['net_worth (in billion $)'].sum()

# Sort the wealth by continent
sorted_wealth_by_continent = wealth_by_continent.sort_values(ascending=False)

# Iterate through each continent and calculate the count of people
people_count_by_continent = {}
for continent in sorted_wealth_by_continent.index:
    total_wealth = sorted_wealth_by_continent[continent]
    people_count = df[df['Continent'] == continent].shape[0]
    people_count_by_continent[continent] = (people_count, total_wealth)

# Display the count of people and total wealth by continent
for continent, (people_count, total_wealth) in people_count_by_continent.items():
    print(f"Continent: {continent}\t People Count: {people_count}\t Total Wealth: {total_wealth}")
# Out:
# Continent: North America	 People Count: 820	 Total Wealth: 4916.2
# Continent: Asia	 People Count: 1030	 Total Wealth: 3699.6
# Continent: Europe	 People Count: 599	 Total Wealth: 2924.7
# Continent: South America	 People Count: 69	 Total Wealth: 234.9
# Continent: Australia	 People Count: 47	 Total Wealth: 183.5
# Continent: Africa	 People Count: 20	 Total Wealth: 90.5
# Continent: Oceania	 People Count: 3	 Total Wealth: 12.7

# %%
# Group the data by Continent and sort by net worth in descending order
grouped_by_continent = df.groupby('Continent', as_index=False).apply(lambda x: x.nlargest(5, 'net_worth (in billion $)'))

# Display the top 5 richest people in each continent
for continent, data in grouped_by_continent.groupby('Continent'):
    print(f"Continent: {continent}")
    print(data[['rank', 'name', 'net_worth (in billion $)']])
    print()
# Out:
# Continent: Africa
#        rank                        name  net_worth (in billion $)
# 0 123   124               Aliko Dangote                      14.2
#   156   157      Johann Rupert & family                      11.1
#   242   242  Nicky Oppenheimer & family                       8.4
#   252   249            Abdulsamad Rabiu                       8.2
#   308   305              Nassef Sawiris                       7.4
#
# Continent: Asia
#       rank            name  net_worth (in billion $)
# 1 8      9   Mukesh Ambani                      83.4
#   14    15  Zhong Shanshan                      68.0
#   23    24    Gautam Adani                      47.2
#   25    26    Zhang Yiming                      45.0
#   32    33     Li Ka-shing                      38.0
#
# Continent: Australia
#        rank                 name  net_worth (in billion $)
# 2 51     52        Gina Rinehart                      27.0
#   81     82       Andrew Forrest                      19.6
# ...

# %%
import matplotlib.pyplot as plt

# Group the data by Continent and sort by net worth in descending order
grouped_by_continent = df.groupby('Continent', as_index=False).apply(lambda x: x.nlargest(5, 'net_worth (in billion $)'))

# Create subplots for each continent
fig, axes = plt.subplots(nrows=len(grouped_by_continent), figsize=(10, 6 * len(grouped_by_continent)))

# Plot the top 5 richest people for each continent
for i, (continent, data) in enumerate(grouped_by_continent.groupby('Continent')):
    ax = axes[i]
    data[['name', 'net_worth (in billion $)']].plot(kind='bar', x='name', y='net_worth (in billion $)', ax=ax)
    ax.set_title(f'Top 5 Richest People in {continent}')
    ax.set_xlabel('Name')
    ax.set_ylabel('Net Worth (in billion $)')
    ax.legend().remove()

plt.tight_layout()
plt.show()

# %%
grouped_by_continent
# Out:
#         rank                                   name  net_worth (in billion $)  \
# 0 123    124                          Aliko Dangote                      14.2
#   156    157                 Johann Rupert & family                      11.1
#   242    242             Nicky Oppenheimer & family                       8.4
#   252    249                       Abdulsamad Rabiu                       8.2
#   308    305                         Nassef Sawiris                       7.4
# 1 8        9                          Mukesh Ambani                      83.4
#   14      15                         Zhong Shanshan                      68.0
#   23      24                           Gautam Adani                      47.2
#   25      26                           Zhang Yiming                      45.0
#   32      33                            Li Ka-shing                      38.0
# 2 51      52                          Gina Rinehart                      27.0
# ...

# %%
import matplotlib.pyplot as plt

# Sum wealth by continent
wealth_by_continent = df.groupby('Continent')['net_worth (in billion $)'].sum()

# Rank continents by wealth
ranked_continents = wealth_by_continent.sort_values(ascending=False)

# Create a bar plot
plt.figure(figsize=(10, 6))
ranked_continents.plot(kind='bar', color='skyblue')
plt.title('Wealth Distribution by Continent')
plt.xlabel('Continent')
plt.ylabel('Total Wealth (in billion $)')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by Continent and Industry, and sum up wealth
wealth_by_continent_industry = df.groupby(['Continent', 'industry'])['net_worth (in billion $)'].sum().reset_index()

# Pivot the data to get it in the right format for plotting
pivot_data = wealth_by_continent_industry.pivot(index='Continent', columns='industry', values='net_worth (in billion $)')

# Create a grouped bar plot
plt.figure(figsize=(12, 6))
sns.set_palette("Set3")
pivot_data.plot(kind='bar', stacked=True)
plt.title('Wealth Distribution by Continent and Industry')
plt.xlabel('Continent')
plt.ylabel('Total Wealth (in billion $)')
plt.xticks(rotation=45)
plt.legend(title='Industry', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter data for North America
north_america_data = df[df['Continent'] == 'North America']

# Count the occurrences of each industry
industry_counts = north_america_data['industry'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=industry_counts.index, y=industry_counts.values, palette="viridis")
plt.title('Industry Distribution of Billionaires in North America')
plt.xlabel('Industry')
plt.ylabel('Number of Billionaires')
plt.xticks(rotation=75)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter data for North America
Europe_data = df[df['Continent'] == 'Europe']

# Count the occurrences of each industry
industry_counts = Europe_data['industry'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=industry_counts.index, y=industry_counts.values, palette="viridis")
plt.title('Industry Distribution of Billionaires in North America')
plt.xlabel('Industry')
plt.ylabel('Number of Billionaires')
plt.xticks(rotation=75)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter data for North America
Asia_data = df[df['Continent'] == 'Asia']

# Count the occurrences of each industry
industry_counts = Asia_data['industry'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=industry_counts.index, y=industry_counts.values, palette="viridis")
plt.title('Industry Distribution of Billionaires in  Asia')
plt.xlabel('Industry')
plt.ylabel('Number of Billionaires')
plt.xticks(rotation=75)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter data for North America
South_america_data = df[df['Continent'] == 'Europe']

# Count the occurrences of each industry
industry_counts = South_america_data['industry'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=industry_counts.index, y=industry_counts.values, palette="viridis")
plt.title('Industry Distribution of Billionaires in South America')
plt.xlabel('Industry')
plt.ylabel('Number of Billionaires')
plt.xticks(rotation=75)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter data for North America
Africa_data = df[df['Continent'] == 'Europe']

# Count the occurrences of each industry
industry_counts = Africa_data['industry'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=industry_counts.index, y=industry_counts.values, palette="viridis")
plt.title('Industry Distribution of Billionaires in  Africa')
plt.xlabel('Industry')
plt.ylabel('Number of Billionaires')
plt.xticks(rotation=75)
plt.tight_layout()

plt.show()
